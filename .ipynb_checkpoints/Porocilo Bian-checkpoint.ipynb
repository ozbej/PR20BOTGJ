# %%
from csv import DictReader
data = list(DictReader(open('podatki/pn2019.csv', 'rt', encoding='utf-8'), delimiter=";"))

for row in data:
    print(row)
# Out:
# OrderedDict([('ZaporednaStevilkaPN', '000001'), ('KlasifikacijaNesrece', 'Z LAZJO TELESNO POSKODBO'), ('UpravnaEnotaStoritve', 'LJUBLJANA'), ('DatumPN', '08.01.2019'), ('UraPN', '13'), ('VNaselju', 'DA'), ('Lokacija', 'NASELJE'), ('VrstaCesteNaselja', 'NASELJE Z ULICNIM SISTEMOM'), ('SifraCesteNaselja', '25001'), ('TekstCesteNaselja', 'LJUBLJANA'), ('SifraOdsekaUlice', '26016'), ('TekstOdsekaUlice', 'KAJUHOVA ULICA'), ('StacionazaDogodka', '42'), ('OpisKraja', 'KRIZISCE'), ('VzrokNesrece', 'NEUSTREZNA VARNOSTNA RAZDALJA'), ('TipNesrece', 'TRCENJE V STOJECE / PARKIRANO VOZILO'), ('VremenskeOkoliscine', 'DEZEVNO'), ('StanjePrometa', 'GOST'), ('StanjeVozisca', 'MOKRO'), ('VrstaVozisca', 'ZGLAJEN ASFALT / BETON'), ('GeoKoordinataX', '101505'), ('GeoKoordinataY', '464773'), ('ZaporednaStevilkaOsebeVPN', '000001001'), ('Povzrocitelj', 'UDELEZENEC'), ('Starost', '50'), ('Spol', 'MOSKI'), ('UEStalnegaPrebivalisca', 'LJUBLJANA'), ('Drzavljanstvo', 'SLOVENIJA'), ('PoskodbaUdelezenca', 'BREZ PO
# ...
